# %%
import numpy
import pandas as pd
import sklearn as scikit_learn

# %%
df_ludnosc = pd.read_csv("../data/ludnosc.csv", sep=";")
df_ludnosc.tail(10)
# Out:
#       Kategoria      Kod               Nazwa  \
# 25864   Wydatki  3200000  ZACHODNIOPOMORSKIE
# 25865   Wydatki  3200000  ZACHODNIOPOMORSKIE
# 25866   Wydatki  3200000  ZACHODNIOPOMORSKIE
# 25867   Wydatki  3200000  ZACHODNIOPOMORSKIE
# 25868   Wydatki  3200000  ZACHODNIOPOMORSKIE
# 25869   Wydatki  3200000  ZACHODNIOPOMORSKIE
# 25870   Wydatki  3200000  ZACHODNIOPOMORSKIE
# 25871   Wydatki  3200000  ZACHODNIOPOMORSKIE
# 25872   Wydatki  3200000  ZACHODNIOPOMORSKIE
# 25873   Wydatki  3200000  ZACHODNIOPOMORSKIE
#
#                                                  Zmienna   Rok Wartosc  \
# 25864  udział wydatków na użytkowanie mieszkania i no...  2011    21,4
# 25865  udział wydatków na użytkowanie mieszkania i no...  2012    20,6
# 25866  udział wydatków na użytkowanie mieszkania i no...  2013    21,5
# 25867  udział wydatków na użytkowanie mieszkania i no...  2014    19,7
# 25868  udział wydatków na użytkowanie mieszkania i no...  2015    19,9
# 25869  udział wydatków na użytkowanie mieszkania i no...  2016    19,9
# 25870  udział wydatków na użytkowanie mieszkania i no...  2017    19,5
# 25871  udział wydatków na użytkowanie mieszkania i no...  2018    19,5
# 25872  udział wydatków na użytkowanie mieszkania i no...  2019    19,3
# 25873  udział wydatków na użytkowanie mieszkania i no...  2020    20,3
#
#       Jednostka miary Atrybut  Unnamed: 8
# 25864               %     NaN         NaN
# 25865               %     NaN         NaN
# 25866               %     NaN         NaN
# 25867               %     NaN         NaN
# 25868               %     NaN         NaN
# 25869               %     NaN         NaN
# 25870               %     NaN         NaN
# 25871               %     NaN         NaN
# 25872               %     NaN         NaN
# 25873               %     NaN         NaN

# %%
kategorie = ["towary i usługi konsumpcyjne", "żywność i napoje bezalkoholowe", "napoje alkoholowe i wyroby tytoniowe", "odzież i obuwie",
             "użytkowanie mieszkania lub domu i nośniki energii", "wyposażenie mieszkania i prowadzenie gospodarstwa domowego", "zdrowie",
             "transport", "łączność", "rekreacja i kultura", "edukacja", "restauracje i hotele", "pozostałe wydatki na towary i usługi"]

# %%
lata = [2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]

# %%
nazwa = ['KUJAWSKO-POMORSKIE', 'LUBELSKIE', 'LUBUSKIE', 'ŁÓDZKIE', 'MAZOWIECKIE', 'ŚWIĘTOKRZYSKIE']

# %%
df_ludnosc['Rok'] = df_ludnosc['Rok'].apply(int)
df_ludnosc['Wartosc'] = df_ludnosc['Wartosc'].apply(str).str.replace(',','.').apply(float)

# %%
df = df_ludnosc[(df_ludnosc['Rok'].isin(lata)) & (df_ludnosc['Nazwa'].isin(nazwa)) & (df_ludnosc['Kategoria'] == 'Wydatki') & (df_ludnosc['Zmienna'].isin(kategorie))].drop(['Kod', 'Jednostka miary', 'Atrybut', 'Unnamed: 8', 'Kategoria'], axis=1)
df = df.reset_index(drop=True)
df
# Out:
#                    Nazwa                               Zmienna   Rok  Wartosc
# 0     KUJAWSKO-POMORSKIE          towary i usługi konsumpcyjne  2003   592.55
# 1     KUJAWSKO-POMORSKIE          towary i usługi konsumpcyjne  2004   596.37
# 2     KUJAWSKO-POMORSKIE          towary i usługi konsumpcyjne  2005   578.22
# 3     KUJAWSKO-POMORSKIE          towary i usługi konsumpcyjne  2006   646.69
# 4     KUJAWSKO-POMORSKIE          towary i usługi konsumpcyjne  2007   707.06
# ...                  ...                                   ...   ...      ...
# 1399      ŚWIĘTOKRZYSKIE  pozostałe wydatki na towary i usługi  2016    57.50
# 1400      ŚWIĘTOKRZYSKIE  pozostałe wydatki na towary i usługi  2017    72.24
# 1401      ŚWIĘTOKRZYSKIE  pozostałe wydatki na towary i usługi  2018    65.38
# 1402      ŚWIĘTOKRZYSKIE  pozostałe wydatki na towary i usługi  2019    64.08
# 1403      ŚWIĘTOKRZYSKIE  pozostałe wydatki na towary i usługi  2020    61.02
#
# [1404 rows x 4 columns]

# %%
df_p = pd.pivot_table(data=df, values='Wartosc', index=['Nazwa', 'Rok'], columns=['Zmienna']).reset_index()  
df_p['Suma'] = df_p[kategorie].sum(axis=1)
df_p
# Out:
# Zmienna               Nazwa   Rok  edukacja  \
# 0        KUJAWSKO-POMORSKIE  2003      7.47
# 1        KUJAWSKO-POMORSKIE  2004      5.59
# 2        KUJAWSKO-POMORSKIE  2005      5.14
# 3        KUJAWSKO-POMORSKIE  2006      5.40
# 4        KUJAWSKO-POMORSKIE  2007      7.96
# ..                      ...   ...       ...
# 103          ŚWIĘTOKRZYSKIE  2016      5.02
# 104          ŚWIĘTOKRZYSKIE  2017      7.25
# 105          ŚWIĘTOKRZYSKIE  2018      7.45
# 106          ŚWIĘTOKRZYSKIE  2019      4.93
# 107          ŚWIĘTOKRZYSKIE  2020      7.74
#
# Zmienna  napoje alkoholowe i wyroby tytoniowe  odzież i obuwie  \
# 0                                       18.82            30.31
# 1                                       17.15            29.86
# 2                                       18.40            29.61
# 3                                       21.10            38.43
# 4                                       22.76            38.99
# ..                                        ...              ...
# 103                                     18.89            57.80
# 104                                     19.97            60.68
# 105                                     23.01            58.92
# 106                                     22.98            53.27
# 107                                     24.63            42.24
#
# Zmienna  pozostałe wydatki na towary i usługi  rekreacja i kultura  \
# 0                                       30.89                35.51
# 1                                       29.18                37.17
# 2                                       26.17                40.29
# 3                                       31.95                46.79
# 4                                       35.18                56.67
# ..                                        ...                  ...
# 103                                     57.50                62.12
# 104                                     72.24                55.85
# 105                                     65.38                55.51
# 106                                     64.08                49.79
# 107                                     61.02                45.04
#
# Zmienna  restauracje i hotele  towary i usługi konsumpcyjne  transport  \
# 0                       10.62                        592.55      60.09
# 1                        9.65                        596.37      48.25
# 2                        7.63                        578.22      48.64
# 3                        9.49                        646.69      57.08
# 4                       11.10                        707.06      64.72
# ..                        ...                           ...        ...
# 103                     32.21                        930.20      72.60
# 104                     37.42                        998.54      83.91
# 105                     46.28                       1030.85     107.91
# 106                     39.33                       1015.24      92.76
# 107                     27.47                        963.59      92.36
#
# Zmienna  użytkowanie mieszkania lub domu i nośniki energii  \
# 0                                                   131.68
# 1                                                   134.51
# 2                                                   123.81
# 3                                                   136.71
# 4                                                   145.66
# ..                                                     ...
# 103                                                 195.53
# 104                                                 200.30
# 105                                                 199.26
# 106                                                 197.27
# 107                                                 187.69
#
# Zmienna  wyposażenie mieszkania i prowadzenie gospodarstwa domowego  zdrowie  \
# 0                                                    28.45             26.38
# 1                                                    35.00             27.77
# 2                                                    30.57             26.34
# 3                                                    35.19             28.95
# 4                                                    41.13             30.63
# ..                                                     ...               ...
# 103                                                  53.00             60.88
# 104                                                  58.40             68.84
# 105                                                  76.93             56.21
# 106                                                  65.25             69.44
# 107                                                  61.08             54.54
#
# Zmienna  łączność  żywność i napoje bezalkoholowe     Suma
# 0           28.19                          178.59  1179.55
# 1           29.26                          186.24  1186.00
# 2           32.31                          185.09  1152.22
# 3           34.86                          193.48  1286.12
# 4           37.52                          204.74  1404.12
# ..            ...                             ...      ...
# 103         46.91                          266.04  1858.70
# 104         49.15                          282.86  1995.41
# 105         34.63                          298.18  2060.52
# 106         46.10                          308.59  2029.03
# 107         49.04                          309.99  1926.43
#
# [108 rows x 16 columns]

# %%
for kategoria in kategorie:
    df_p[kategoria] = round((df_p[kategoria] / df_p['Suma'])*100, 2)
df_p
# Out:
# Zmienna               Nazwa   Rok  edukacja  \
# 0        KUJAWSKO-POMORSKIE  2003      0.63
# 1        KUJAWSKO-POMORSKIE  2004      0.47
# 2        KUJAWSKO-POMORSKIE  2005      0.45
# 3        KUJAWSKO-POMORSKIE  2006      0.42
# 4        KUJAWSKO-POMORSKIE  2007      0.57
# ..                      ...   ...       ...
# 103          ŚWIĘTOKRZYSKIE  2016      0.27
# 104          ŚWIĘTOKRZYSKIE  2017      0.36
# 105          ŚWIĘTOKRZYSKIE  2018      0.36
# 106          ŚWIĘTOKRZYSKIE  2019      0.24
# 107          ŚWIĘTOKRZYSKIE  2020      0.40
#
# Zmienna  napoje alkoholowe i wyroby tytoniowe  odzież i obuwie  \
# 0                                        1.60             2.57
# 1                                        1.45             2.52
# 2                                        1.60             2.57
# 3                                        1.64             2.99
# 4                                        1.62             2.78
# ..                                        ...              ...
# 103                                      1.02             3.11
# 104                                      1.00             3.04
# 105                                      1.12             2.86
# 106                                      1.13             2.63
# 107                                      1.28             2.19
#
# Zmienna  pozostałe wydatki na towary i usługi  rekreacja i kultura  \
# 0                                        2.62                 3.01
# 1                                        2.46                 3.13
# 2                                        2.27                 3.50
# 3                                        2.48                 3.64
# 4                                        2.51                 4.04
# ..                                        ...                  ...
# 103                                      3.09                 3.34
# 104                                      3.62                 2.80
# 105                                      3.17                 2.69
# 106                                      3.16                 2.45
# 107                                      3.17                 2.34
#
# Zmienna  restauracje i hotele  towary i usługi konsumpcyjne  transport  \
# 0                        0.90                         50.24       5.09
# 1                        0.81                         50.28       4.07
# 2                        0.66                         50.18       4.22
# 3                        0.74                         50.28       4.44
# 4                        0.79                         50.36       4.61
# ..                        ...                           ...        ...
# 103                      1.73                         50.05       3.91
# 104                      1.88                         50.04       4.21
# 105                      2.25                         50.03       5.24
# 106                      1.94                         50.04       4.57
# 107                      1.43                         50.02       4.79
#
# Zmienna  użytkowanie mieszkania lub domu i nośniki energii  \
# 0                                                    11.16
# 1                                                    11.34
# 2                                                    10.75
# 3                                                    10.63
# 4                                                    10.37
# ..                                                     ...
# 103                                                  10.52
# 104                                                  10.04
# 105                                                   9.67
# 106                                                   9.72
# 107                                                   9.74
#
# Zmienna  wyposażenie mieszkania i prowadzenie gospodarstwa domowego  zdrowie  \
# 0                                                     2.41              2.24
# 1                                                     2.95              2.34
# 2                                                     2.65              2.29
# 3                                                     2.74              2.25
# 4                                                     2.93              2.18
# ..                                                     ...               ...
# 103                                                   2.85              3.28
# 104                                                   2.93              3.45
# 105                                                   3.73              2.73
# 106                                                   3.22              3.42
# 107                                                   3.17              2.83
#
# Zmienna  łączność  żywność i napoje bezalkoholowe     Suma
# 0            2.39                           15.14  1179.55
# 1            2.47                           15.70  1186.00
# 2            2.80                           16.06  1152.22
# 3            2.71                           15.04  1286.12
# 4            2.67                           14.58  1404.12
# ..            ...                             ...      ...
# 103          2.52                           14.31  1858.70
# 104          2.46                           14.18  1995.41
# 105          1.68                           14.47  2060.52
# 106          2.27                           15.21  2029.03
# 107          2.55                           16.09  1926.43
#
# [108 rows x 16 columns]

# %%
di = {'DOLNOŚLĄSKIE' : 0, 'KUJAWSKO-POMORSKIE' : 1, 'LUBELSKIE' : 2, 'LUBUSKIE' : 3, 'ŁÓDZKIE' : 4, 'MAŁOPOLSKIE' : 5, 'MAZOWIECKIE' : 6, 'OPOLSKIE' : 7,
      'PODKARPACKIE' : 8, 'PODLASKIE' : 9, 'POMORSKIE' : 10, 'ŚLĄSKIE' : 11, 'ŚWIĘTOKRZYSKIE' : 12, 'WARMIŃSKO-MAZURSKIE' : 13, 'WIELKOPOLSKIE' : 14,
      'ZACHODNIOPOMORSKIE' : 15}
df_p = df_p.replace({'Nazwa': di})
df_p
# Out:
# Zmienna  Nazwa   Rok  edukacja  napoje alkoholowe i wyroby tytoniowe  \
# 0            1  2003      0.63                                  1.60
# 1            1  2004      0.47                                  1.45
# 2            1  2005      0.45                                  1.60
# 3            1  2006      0.42                                  1.64
# 4            1  2007      0.57                                  1.62
# ..         ...   ...       ...                                   ...
# 103         12  2016      0.27                                  1.02
# 104         12  2017      0.36                                  1.00
# 105         12  2018      0.36                                  1.12
# 106         12  2019      0.24                                  1.13
# 107         12  2020      0.40                                  1.28
#
# Zmienna  odzież i obuwie  pozostałe wydatki na towary i usługi  \
# 0                   2.57                                  2.62
# 1                   2.52                                  2.46
# 2                   2.57                                  2.27
# 3                   2.99                                  2.48
# 4                   2.78                                  2.51
# ..                   ...                                   ...
# 103                 3.11                                  3.09
# 104                 3.04                                  3.62
# 105                 2.86                                  3.17
# 106                 2.63                                  3.16
# 107                 2.19                                  3.17
#
# Zmienna  rekreacja i kultura  restauracje i hotele  \
# 0                       3.01                  0.90
# 1                       3.13                  0.81
# 2                       3.50                  0.66
# 3                       3.64                  0.74
# 4                       4.04                  0.79
# ..                       ...                   ...
# 103                     3.34                  1.73
# 104                     2.80                  1.88
# 105                     2.69                  2.25
# 106                     2.45                  1.94
# 107                     2.34                  1.43
#
# Zmienna  towary i usługi konsumpcyjne  transport  \
# 0                               50.24       5.09
# 1                               50.28       4.07
# 2                               50.18       4.22
# 3                               50.28       4.44
# 4                               50.36       4.61
# ..                                ...        ...
# 103                             50.05       3.91
# 104                             50.04       4.21
# 105                             50.03       5.24
# 106                             50.04       4.57
# 107                             50.02       4.79
#
# Zmienna  użytkowanie mieszkania lub domu i nośniki energii  \
# 0                                                    11.16
# 1                                                    11.34
# 2                                                    10.75
# 3                                                    10.63
# 4                                                    10.37
# ..                                                     ...
# 103                                                  10.52
# 104                                                  10.04
# 105                                                   9.67
# 106                                                   9.72
# 107                                                   9.74
#
# Zmienna  wyposażenie mieszkania i prowadzenie gospodarstwa domowego  zdrowie  \
# 0                                                     2.41              2.24
# 1                                                     2.95              2.34
# 2                                                     2.65              2.29
# 3                                                     2.74              2.25
# 4                                                     2.93              2.18
# ..                                                     ...               ...
# 103                                                   2.85              3.28
# 104                                                   2.93              3.45
# 105                                                   3.73              2.73
# 106                                                   3.22              3.42
# 107                                                   3.17              2.83
#
# Zmienna  łączność  żywność i napoje bezalkoholowe     Suma
# 0            2.39                           15.14  1179.55
# 1            2.47                           15.70  1186.00
# 2            2.80                           16.06  1152.22
# 3            2.71                           15.04  1286.12
# 4            2.67                           14.58  1404.12
# ..            ...                             ...      ...
# 103          2.52                           14.31  1858.70
# 104          2.46                           14.18  1995.41
# 105          1.68                           14.47  2060.52
# 106          2.27                           15.21  2029.03
# 107          2.55                           16.09  1926.43
#
# [108 rows x 16 columns]

# %%
df_p.isna().sum()
# Out:
# Zmienna
# Nazwa                                                         0
# Rok                                                           0
# edukacja                                                      0
# napoje alkoholowe i wyroby tytoniowe                          0
# odzież i obuwie                                               0
# pozostałe wydatki na towary i usługi                          0
# rekreacja i kultura                                           0
# restauracje i hotele                                          0
# towary i usługi konsumpcyjne                                  0
# transport                                                     0
# użytkowanie mieszkania lub domu i nośniki energii             0
# wyposażenie mieszkania i prowadzenie gospodarstwa domowego    0
# zdrowie                                                       0
# łączność                                                      0
# żywność i napoje bezalkoholowe                                0
# Suma                                                          0
# dtype: int64

# %%
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# %%
# Kolumny od edukacji do żywność i napoje bezalkoholowe
X_to_pca = np.array(df_p.iloc[:,2:15])
X_to_pca
# Out:
# array([[ 0.63,  1.6 ,  2.57, ...,  2.24,  2.39, 15.14],
#        [ 0.47,  1.45,  2.52, ...,  2.34,  2.47, 15.7 ],
#        [ 0.45,  1.6 ,  2.57, ...,  2.29,  2.8 , 16.06],
#        ...,
#        [ 0.36,  1.12,  2.86, ...,  2.73,  1.68, 14.47],
#        [ 0.24,  1.13,  2.63, ...,  3.42,  2.27, 15.21],
#        [ 0.4 ,  1.28,  2.19, ...,  2.83,  2.55, 16.09]])

# %%
pipeline = make_pipeline(StandardScaler(), PCA(3))
X = pipeline.fit_transform(X_to_pca)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, roc_auc_
#        [ 4.09067023e-01, -1.97342792e+00,  7.90286462e-02],
#        [ 1.26391751e-01, -1.58620128e+00,  2.54207545e-01],
#        [ 9.61663797e-01, -1.86312313e+00,  2.34761777e-01],
#        [ 9.00859553e-01, -5.58523879e-01,  7.99542083e-01],
#        [ 1.50095703e+00,  5.15430463e-01,  5.13663056e-01],
#        [ 1.97192743e+00,  1.12492539e-01,  7.42372693e-01],
#        [ 2.97520321e+00,  2.33180265e-01,  8.30750124e-01],
#        [ 2.98784241e+00,  1.20019205e+00,  1.15385907e+00],
#        [ 2.73687204e+00,  1.12340529e+00,  1.66332083e+00],
#        [ 3.30249990e+00, -3.70061721e-02,  5.90278796e+00],
#        [ 5.00987409e-01,  1.12213187e+00,  2.34139750e+00],
#        [-2.70182694e+00,  7.84349439e-01, -1.97679267e+00],
#        [-3.26650809e+00,  1.26724399e+00, -1.92432244e+00],
#        [-2.68774782e+00,  2.47740719e+00, -1.54230029e+00],
#        [-3.09399717e+00,  1.79441227e+00, -1.74009663e+00],
#        [-1.99317578e+00,  1.89067402e+00, -2.29553778e+00],
#        [-1.49660509e+00,  1.20337633e+00, -1.34205662e+00],
#        [-2.48050422e+00,  1.09500737e+00, -1.25128276e+00],
#        [-2.77400955e+00,  1.30790852e+00, -8.64135558e-01],
#        [-2.89882134e+00,  1.37080021e+00, -7.14786258e-01],
#        [-2.50781450e+00,  1.16186889e+00, -3.63953923e-01],
#        [-1.70404724e+00,  1.53720160e+00, -1.09611614e+00],
#        [ 2.68518804e-01,  2.49417089e+00, -9.28953116e-01],
#        [-5.29294507e-01,  2.37130441e+00, -1.57401536e+00],
#        [ 3.40012808e-01,  2.94593509e+00, -1.23083894e+00],
#        [ 1.58917778e+00,  3.70089576e+00, -8.49558930e-01],
#        [ 1.71958428e+00,  3.43188544e+00,  7.76226890e-02],
#        [ 8.63981145e-01,  4.11621094e+00, -4.04322695e-03],
#        [-8.70519970e-01,  3.01609383e+00,  9.46291008e-01]])

# %%
y = df_p['Nazwa']
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 103    12
# 104    12
# 105    12
# 106    12
# 107    12
# Name: Nazwa, Length: 108, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=43)

# %%
k_range = range(1,10)
error_rate = []

for i in range(1,10):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))

# %%
plt.figure(figsize=(10,6))
plt.plot(k_range, error_rate, color='blue', linestyle='dashed', marker='o', markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
knn = KNeighborsClassifier(n_neighbors=2)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
y_pred = knn.predict(X_test)
print(classification_report(y_test, y_pred))
print(f"Accuracy: {round(knn.score(X_test, y_test), 3)*100}%")
# Out:
#               precision    recall  f1-score   support
#
#            1       0.83      0.56      0.67         9
#            2       1.00      1.00      1.00         3
#            3       0.00      0.00      0.00         1
#            4       1.00      1.00      1.00         2
#            6       1.00      1.00      1.00         4
#           12       1.00      1.00      1.00         3
#
#     accuracy                           0.77        22
#    macro avg       0.81      0.76      0.78        22
# weighted avg       0.89      0.77      0.82        22
#
# Accuracy: 77.3%

# %%
y_pred
# Out:
# array([ 1,  2,  2,  1, 12,  6,  6,  2,  1,  4,  6,  1, 12,  6, 12,  4,  3,
#         1,  3,  3,  3,  1], dtype=int64)

# %%
plt.scatter(X_test[:,0], X_test[:,1], c=y_pred, marker='^')
plt.show()
